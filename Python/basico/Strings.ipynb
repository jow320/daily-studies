# %% [markdown]
# # Strings

# %%
s= "olá"
t= "mundo"
s + " " + t
# Out:
# 'olá mundo'

# %%
s * 3
# Out:
# 'oláoláolá'

# %%
s * t #não funciona
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3103254802.py in <cell line: 0>()
# ----> 1 s * t #não funciona
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
5 * "A"
# Out:
# 'AAAAA'

# %%
"m" in t #case sensitive, não há "M" apenas "m"
# Out:
# True

# %%
len(t) #mundo, len é length, diz o tamanho da string
# Out:
# 5

# %%
type("3")
# Out:
# str
