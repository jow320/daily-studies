# %% [markdown]
# # Váriaveis

# %%
x=10

# %%
x
# Out:
# 10

# %%
X #python é case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2243803019.py in <cell line: 0>()
# ----> 1 X
#
# NameError: name 'X' is not defined

# %%
x+5
# Out:
# 15

# %%
y=15

# %%
x+y
# Out:
# 25

# %%
varau= 12

# %%
varAu = 15

# %%
varau, varAu
# Out:
# (12, 15)
