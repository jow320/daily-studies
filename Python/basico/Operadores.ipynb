# %% [markdown]
# Operadores -
#
# Soma, Subtração, Multiplicação e Divisão

# %%
4+6
# Out:
# 10

# %%
2.5+3
# Out:
# 5.5

# %% [markdown]
# Subtração

# %%
10-20
# Out:
# -10

# %%
20-1.5
# Out:
# 18.5

# %% [markdown]
# Multiplicação

# %%
10*2
# Out:
# 20

# %%
30*1.5
# Out:
# 45.0

# %%
-4*2
# Out:
# -8

# %% [markdown]
# Divisão

# %%
10/2
# Out:
# 5.0

# %%
40/1
# Out:
# 40.0

# %%
40/1.5
# Out:
# 26.666666666666668

# %%
40//1.5 #retorna apenas o inteiro
# Out:
# 26.0

# %%
40%1.5 #retorna o resto
# Out:
# 1.0
