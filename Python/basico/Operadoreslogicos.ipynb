# %% [markdown]
# # Operadores lógicos

# %%
8>4
# Out:
# True

# %%
6>10

# %%
8>=8
# Out:
# True

# %%
10<20
# Out:
# True

# %%
10<10
# Out:
# False

# %%
20<21
# Out:
# True

# %%
20<=20
# Out:
# True

# %%
5==5
# Out:
# True

# %%
5==7
# Out:
# False

# %%
5!=5
# Out:
# False

# %%
5!=6
# Out:
# True
