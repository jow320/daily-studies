# %% [markdown]
# Esse é meu primeiro programa no googlecollab

# %%
print("Olá mundo")
# Out:
# Olá mundo

# %%
print("Esse é meu primeiro programa em Python")
# Out:
# Esse é meu primeiro programa em Python
